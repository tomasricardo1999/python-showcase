# %% [markdown]
# <a href="https://colab.research.google.com/github/tomasricardo1999/python-showcase/blob/main/Sandbox/Sanbox_Tests_and_Reminders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://www.youtube.com/watch?v=ix9cRaBkVe0

# Strings
name = "Tomás Antunes Ricardo"
first_name = "Tomás"
surname = "Antunes Ricardo"
food = "Arroz de Tamboril"
email = "tomasricardo1999@gmail.com"

# Integers

age = 26
quantity = 3
num_of_students = 30

#Float

price = 10.99
gpa = 3.2

#Boolean

is_student = False
for_sale = True
is_online = True

#Prints
print("Hello World")
print(first_name)
print(f"Hello {first_name}, how are you? Are you a student?: {is_student}")

#IF ELSE Condition

if is_student == True:
  print(f"{first_name} is a student")
else:
  print(f"{first_name} is not a student")


#TypeCasting


print(type(price))
print(f"{int(price)} + 1")


#Input

name = input("What is your name?: ")
age = int(input("What is your age?: "))

age = age + 1

print(f"My name is {name} and I am {age} years old")
# Out:
# Hello World
# Tomás
# Hello Tomás, how are you? Are you a student?: False
# Tomás is not a student
# <class 'float'>
# 10 + 1
# What is your name?: ff
# What is your age?: 3
# My name is ff and I am 3 years old
