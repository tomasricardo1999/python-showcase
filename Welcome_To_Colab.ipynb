# %% [markdown]
# <a href="https://colab.research.google.com/github/tomasricardo1999/python-showcase/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
print("Hello World")
# Out:
# Hello World
